# %%
import re
import numpy as np
import ast
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter
import pickle

# %%
df_groups = pd.read_csv("data/groups_wMembers3.csv")
df_groups
# Out:
#       pageid                           title  \
# 0     489818              A Friend in London
# 1     157530                            Ache
# 2     255559                      ADS (band)
# 3     976777                        Agathorn
# 4     493993            Alabama Black Snakes
# ...      ...                             ...
# 1029   37360          Odense Symfoniorkester
# 1030  162784       Sjællands Symfoniorkester
# 1031   10733  Sønderjyllands Symfoniorkester
# 1032  369172         Aalborg Symfoniorkester
# 1033  373862          Aarhus Symfoniorkester
#
#                                          cleaned_member  \
# 0                                         ['Tim Schou']
# 1     ['Per Wium', 'Peter Mellin', 'Finn Olafsson', ...
# 2     ['Michael Funder Thorlasius', 'Stig Pedersen',...
# 3                                                    []
# 4     ['Jonas Jessen', 'Hank Lee Tuffer', 'Mads Øste...
# ...                                                 ...
# 1029  ['Bjarne Hansen', 'Ulrike Kipp', 'Michaela Fuk...
# 1030  ['Ole Böhn', 'Harry Gram-Jensen', 'Fritz O. Ja...
# 1031  ['Anne Augustinsson', 'Jesper Hindø', 'Nikolai...
# 1032  ['Marius Ungureanu', 'Ib Dirkov', 'Moshe Atzmo...
# 1033  ['Eugene Hye-Knudsen', 'Marc Soustrot', 'Svend...
#
#                                            disc_members  \
# 0     ['Tim Schou', 'Esben Svane', 'Aske Damm Brammi...
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1029                                                 []
# 1030                                                 []
# 1031                                                 []
# 1032                                                 []
# 1033                                                 []
#
#                                             all_members
# 0     ['Aske Damm Bramming', 'Esben Svane', 'Sebasti...
# 1     ['Finn Olafsson', 'Per Wium', 'Peter Mellin', ...
# 2     ['Karsten Hjarsø', 'Lars Top-Galia', 'Martin K...
# 3                                                    []
# 4     ['Gustav Pontoppidan', 'Hank Lee Tuffer', 'Jon...
# ...                                                 ...
# 1029  ['Alf Vestergaard', 'Anca Bold', 'Angelika Wag...
# 1030  ['Fritz O. Jacobsen', 'Harry Gram-Jensen', 'Il...
# 1031  ['Anne Augustinsson', 'Brian Quist Jørgensen',...
# 1032  ['Bettina Ejlerts Jensen', 'Bo Juel Christians...
# 1033  ['Ananna Lützhøft', 'Anders Larsen (2)', 'Anik...
#
# [1034 rows x 5 columns]

# %%
cleand_df_groups = df_groups[df_groups['all_members'].apply(len) > 2]
cleand_df_groups.loc[:, 'all_members'] = cleand_df_groups['all_members'].apply(ast.literal_eval)
cleand_df_groups
# Out:
#       pageid                           title  \
# 0     489818              A Friend in London
# 1     157530                            Ache
# 2     255559                      ADS (band)
# 4     493993            Alabama Black Snakes
# 5     279528                  The Alligators
# ...      ...                             ...
# 1029   37360          Odense Symfoniorkester
# 1030  162784       Sjællands Symfoniorkester
# 1031   10733  Sønderjyllands Symfoniorkester
# 1032  369172         Aalborg Symfoniorkester
# 1033  373862          Aarhus Symfoniorkester
#
#                                          cleaned_member  \
# 0                                         ['Tim Schou']
# 1     ['Per Wium', 'Peter Mellin', 'Finn Olafsson', ...
# 2     ['Michael Funder Thorlasius', 'Stig Pedersen',...
# 4     ['Jonas Jessen', 'Hank Lee Tuffer', 'Mads Øste...
# 5     ['Ole Ballund', 'Jens Dan', 'Niels Mathiasen',...
# ...                                                 ...
# 1029  ['Bjarne Hansen', 'Ulrike Kipp', 'Michaela Fuk...
# 1030  ['Ole Böhn', 'Harry Gram-Jensen', 'Fritz O. Ja...
# 1031  ['Anne Augustinsson', 'Jesper Hindø', 'Nikolai...
# 1032  ['Marius Ungureanu', 'Ib Dirkov', 'Moshe Atzmo...
# 1033  ['Eugene Hye-Knudsen', 'Marc Soustrot', 'Svend...
#
#                                            disc_members  \
# 0     ['Tim Schou', 'Esben Svane', 'Aske Damm Brammi...
# 1                                                    []
# 2                                                    []
# 4                                                    []
# 5                                                    []
# ...                                                 ...
# 1029                                                 []
# 1030                                                 []
# 1031                                                 []
# 1032                                                 []
# 1033                                                 []
#
#                                             all_members
# 0     [Aske Damm Bramming, Esben Svane, Sebastian Vi...
# 1     [Finn Olafsson, Per Wium, Peter Mellin, Steen ...
# 2     [Karsten Hjarsø, Lars Top-Galia, Martin Krogh,...
# 4     [Gustav Pontoppidan, Hank Lee Tuffer, Jonas Je...
# 5     [Jens Dan, Morten Kjeldsen, Niels Mathiasen, O...
# ...                                                 ...
# 1029  [Alf Vestergaard, Anca Bold, Angelika Wagner, ...
# 1030  [Fritz O. Jacobsen, Harry Gram-Jensen, Ilse O....
# 1031  [Anne Augustinsson, Brian Quist Jørgensen, Hen...
# 1032  [Bettina Ejlerts Jensen, Bo Juel Christiansen,...
# 1033  [Ananna Lützhøft, Anders Larsen (2), Anika Tel...
#
# [868 rows x 5 columns]

# %%
cleand_df_groups['all_members'][0]
# Out:
# ['Aske Damm Bramming', 'Esben Svane', 'Sebastian Vinther Olsen', 'Tim Schou']

# %%
B = nx.Graph()
for _, row in cleand_df_groups.iterrows():
    band = row['title']
    B.add_node(band, bipartite='band')
    for musician in row['all_members']:
        B.add_node(musician, bipartite='musician')
        B.add_edge(band, musician)

# %%
bands = [n for n,d in B.nodes(data=True) if d['bipartite']=='band']
musicians = [n for n,d in B.nodes(data=True) if d['bipartite']=='musician']

# %%
pos = nx.spring_layout(B, seed=43, k=0.05)

# %%
plt.figure(figsize=(12,12))

# Draw musician nodes (no labels)
nx.draw_networkx_nodes(
    B, pos,
    nodelist=musicians,
    node_color='limegreen',
    node_size=10,
    label='Musicians'
)

# Draw band nodes
nx.draw_networkx_nodes(
    B, pos,
    nodelist=bands,
    node_color='royalblue',
    node_size=50,
    label='Groups'
)

# Draw edges
nx.draw_networkx_edges(B, pos, alpha=0.3, width=0.5)


plt.title("Bipartite Musician ↔ Group Network")
plt.legend(scatterpoints=1)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Interactive graph HTML

# %%
import plotly.graph_objects as go

# %%
edge_x, edge_y = [], []
for u, v in B.edges():
    x0, y0 = pos[u]; x1, y1 = pos[v]
    edge_x += [x0, x1, None]
    edge_y += [y0, y1, None]

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    mode='lines',
    line=dict(width=0.5, color='gray'),
    hoverinfo='none'
)

# %%
node_x, node_y, node_color, node_text = [], [], [], []
for n, d in B.nodes(data=True):
    x, y = pos[n]
    node_x.append(x); node_y.append(y)
    if d['bipartite']=='group':
        node_color.append('royalblue')
        node_text.append(f"<b>Group:</b> {n}")
    else:
        node_color.append('limegreen')
        node_text.append(f"<b>Musician:</b> {n}")

# %%
node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    marker=dict(size=8, color=node_color),
    text=node_text,
    hoverinfo='text'
)

# %%
fig = go.Figure(
    data=[edge_trace, node_trace],
    layout=go.Layout(
        title="Interactive Bipartite Musician ↔ Group Network",
        showlegend=False,
        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        margin=dict(t=40, l=0, r=0, b=0)
    )
)
fig.write_html("docs/bipartite.html", include_plotlyjs="cdn")
print("→ docs/network_interactive.html written")
# Out:
# → docs/network_interactive.html written
